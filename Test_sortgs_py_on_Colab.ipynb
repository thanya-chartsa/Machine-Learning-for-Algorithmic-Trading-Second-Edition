# %% [markdown]
# <a href="https://colab.research.google.com/github/thanya-chartsa/Machine-Learning-for-Algorithmic-Trading-Second-Edition/blob/master/Test_sortgs_py_on_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Try `sortgs.py` on Google Colab
# This is a jupyter envirnment where you can try the code of the repository without installing anything. The only limitation is the robot checking problem which would require selenium and manual solution of the captchas, but for trying a few keywords, it should work!
#
# > **INSTRUCTIONS:** If this is the first time you are using a jupyter environment, you simply have to run the code blocks using the keyword `SHIFT` + `ENTER`. Make sure to update the keyword parameters when required.
#
# First, let's clone the repository:

# %%
# !git clone https://github.com/WittmannF/sort-google-scholar.git
# Out:
# Cloning into 'sort-google-scholar'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 247 (delta 4), reused 7 (delta 1), pack-reused 232
# Receiving objects: 100% (247/247), 140.53 KiB | 12.78 MiB/s, done.
# Resolving deltas: 100% (110/110), done.

# %% [markdown]
# Now, let's open the folder from the cloned repository:

# %%
cd sort-google-scholar/
# Out:
# /content/sort-google-scholar

# %% [markdown]
# Next, let's run the code. Make sure to change the keyword that you would like to have it ranked.

# %%
# Change keyword to wthat you would like to check
# !python sortgs.py --kw "skin cancer" --sortby "cit/year"
# Out:
# Loading next 10 results
# Loading next 20 results
# Loading next 30 results
# Loading next 40 results
# Loading next 50 results
# Loading next 60 results
# Loading next 70 results
# Loading next 80 results
# Loading next 90 results
# Loading next 100 results
# Loading next 110 results
# Loading next 120 results
# Loading next 130 results
# Loading next 140 results
# Loading next 150 results
# Loading next 160 results
# Loading next 170 results
# Loading next 180 results
# Loading next 190 results
# Loading next 200 results
# Loading next 210 results
# Loading next 220 results
# Loading next 230 results
# Loading next 240 results
# Loading next 250 results
# Loading next 260 results
# Loading next 270 results
# Loading next 280 results
# Loading next 290 results
# Loading next 300 results
# Loading next 310 results
# Loading next 320 results
# Loading next 330 results
# Loading next 340 results
# Loading next 350 results
# Loading next 360 results
# Loading next 370 results
# Loading next 380 results
# Loading next 390 results
# Loading next 400 results
# Loading next 410 results
# Loading next 420 results
# Loading next 430 results
# Loading next 440 results
# Loading next 450 results
# Loading next 460 results
# Loading next 470 results
# Loading next 480 results
# Loading next 490 results
# Loading next 500 results
# Loading next 510 results
# Loading next 520 results
# Loading next 530 results
# Loading next 540 results
# Loading next 550 results
# Loading next 560 results
# Loading next 570 results
# Loading next 580 results
# Loading next 590 results
# Loading next 600 results
# Loading next 610 results
# Loading next 620 results
# Loading next 630 results
# Loading next 640 results
# Loading next 650 results
# Loading next 660 results
# Loading next 670 results
# Loading next 680 results
# Loading next 690 results
# Loading next 700 results
# Loading next 710 results
# Loading next 720 results
# Loading next 730 results
# Loading next 740 results
# Loading next 750 results
# Loading next 760 results
# Loading next 770 results
# Loading next 780 results
# Loading next 790 results
# Loading next 800 results
# Loading next 810 results
# Loading next 820 results
# Loading next 830 results
# Loading next 840 results
# Loading next 850 results
# Loading next 860 results
# Loading next 870 results
# Loading next 880 results
# Loading next 890 results
# Loading next 900 results
# Loading next 910 results
# Loading next 920 results
# Loading next 930 results
# Loading next 940 results
# Robot checking detected, handling with selenium (if installed)
# No module named 'selenium'
# Please install Selenium and chrome webdriver for manual checking of captchas
# Loading...
# No success. The following error was raised:
# local variable 'Options' referenced before assignment
# Loading next 950 results
# Robot checking detected, handling with selenium (if installed)
# No module named 'selenium'
# Please install Selenium and chrome webdriver for manual checking of captchas
# Loading...
# No success. The following error was raised:
# local variable 'Options' referenced before assignment
# Loading next 960 results
# Robot checking detected, handling with selenium (if installed)
# No module named 'selenium'
# Please install Selenium and chrome webdriver for manual checking of captchas
# Loading...
# No success. The following error was raised:
# local variable 'Options' referenced before assignment
# Loading next 970 results
# Robot checking detected, handling with selenium (if installed)
# No module named 'selenium'
# Please install Selenium and chrome webdriver for manual checking of captchas
# Loading...
# No success. The following error was raised:
# local variable 'Options' referenced before assignment
# Loading next 980 results
# Robot checking detected, handling with selenium (if installed)
# No module named 'selenium'
# Please install Selenium and chrome webdriver for manual checking of captchas
# Loading...
# No success. The following error was raised:
# local variable 'Options' referenced before assignment
# Loading next 990 results
# Loading next 1000 results
# Column name to be sorted not found. Sorting by the number of citations...
# 'cit/year1'
#                                              Author  ... cit/year
# Rank                                                 ...
# 107   Esteva, B Kuprel, RA Novoa, J Ko, SM Swetter…  ...     1405
# 249                    Brash, JA Rudolph, JA Simon…  ...       72
# 12                             Armstrong, A Kricker  ...       96
# 64                           Lomas, J Leonardi‐Bee…  ...      159
# 183     Ziegler, AS Jonason, DJ Leffellt, JA Simon…  ...       60
# ...                                             ...  ...      ...
# 898            Arora, AK Dubey, ZA Jaffery, A Rocha  ...       16
# 677                            Becker, A Zur Hausen  ...        3
# 627         Khan, T Akram, M Sharif, S Kadry, Y Nam  ...       10
# 887                                 Baldwin, J Dunn  ...        2
# 595          Allen, AJ Martin, VA Snaidr, R Eggins…  ...        3
#
# [930 rows x 8 columns]

# %% [markdown]
# > _**NOTE:** It is normal to get some warnings, for example year not found or author not found. However, if you get the robot checking warning, then it might not work anymore in the IP that you have on Google Colab. You can try going in 'Runtime' > 'Disconnect and delete runtime' to get a new IP. If the problem persists, then you will have to run locally using selenium and solve the captchas manually. Make sure to avoid running this code too often to avoid the robot checking problem._
#
# Next, you will see that a csv file with the name of the keyword was created (which is `skin_cancer.csv` in my case).

# %%
ls
# Out:
# examples/         skin_cancer.csv          test/
# README.md         sort-google-scholar-V1/  Test_sortgs_py_on_Colab.ipynb
# requirements.txt  sortgs.py*

# %% [markdown]
# Let's import this file to visualize some results (make sure to change `skin_cancer.csv` to the file name that was created in your case):

# %%
import pandas as pd
df = pd.read_csv('skin_cancer.csv') # OBS: Update the file name

# %%
df.head(20)
# Out:
#     Rank                                         Author  \
# 0    107  Esteva, B Kuprel, RA Novoa, J Ko, SM Swetter…
# 1    249                   Brash, JA Rudolph, JA Simon…
# 2     12                           Armstrong, A Kricker
# 3     64                         Lomas, J Leonardi‐Bee…
# 4    183    Ziegler, AS Jonason, DJ Leffellt, JA Simon…
# 5    332                 Euvrard, J Kanitakis, A Claudy
# 6      3                              Diepgen, V Mahler
# 7    223              Rogers, MA Weinstock, SR Feldman…
# 8     27               Rogers, MA Weinstock, AR Harris…
# 9     22                           Miller, MA Weinstock
# 10    55                                         Setlow
# 11    67                Tseng, HM Chu, SW How, JM Fong…
# 12     8                          Narayanan, RN Saladi…
# 13     5                    Madan, JT Lear, RM Szeimies
# 14   363                                          Tseng
# 15   312       Jensen, S Hansen, B Møller, T Leivestad…
# 16    88                                Leiter, C Garbe
# 17   613                 Ziegler, DJ Leffell, S Kunala…
# 18   154                 Woodward, BE Cole, VP Wallace…
# 19   153                                 Berg, CC Otley
#
#                                                 Title  Citations  Year  \
# 0   Dermatologist-level classification of skin can...       9837  2017
# 1   A role for sunlight in skin cancer: UV-induced...       2380  1991
# 2          The epidemiology of UV induced skin cancer       2200  2001
# 3   A systematic review of worldwide incidence of ...       1909  2012
# 4         Sunburn and p53 in the onset of skin cancer       1812  1994
# 5            Skin cancers after organ transplantation       1797  2003
# 6                     The epidemiology of skin cancer       1758  2002
# 7   Incidence estimate of nonmelanoma skin cancer ...       1572  2015
# 8   Incidence estimate of nonmelanoma skin cancer ...       1463  2010
# 9   Nonmelanoma skin cancer in the United States: ...       1434  1994
# 10  The wavelengths in sunlight effective in produ...       1402  1974
# 11  Prevalence of skin cancer in an endemic area o...       1215  1968
# 12              Ultraviolet radiation and skin cancer       1130  2010
# 13                           Non-melanoma skin cancer       1024  2010
# 14  Effects and dose-response relationships of ski...       1019  1977
# 15  Skin cancer in kidney and heart transplant rec...        974  1999
# 16  Epidemiology of melanoma and nonmelanoma skin ...        938  2008
# 17  Mutation hotspots due to sunlight in the p53 g...        914  1993
# 18  Terahertz pulse imaging in reflection geometry...        900  2002
# 19  Skin cancer in organ transplant recipients: ep...        852  2002
#
#                   Publisher                                            Venue  \
# 0                nature.com                                           nature
# 1    National Acad Sciences                             Proceedings of the …
# 2                  Elsevier   Journal of photochemistry and photobiology B …
# 3          academic.oup.com                             British Journal of …
# 4                nature.com                                           Nature
# 5          Mass Medical Soc                         New England Journal of …
# 6          academic.oup.com                   British Journal of Dermatology
# 7           jamanetwork.com                                           JAMA …
# 8           jamanetwork.com                                    Archives of …
# 9                  Elsevier             Journal of the American Academy of …
# 10   National Acad Sciences         Proceedings of the National Academy of …
# 11         academic.oup.com                          … the national Cancer …
# 12     Wiley Online Library                       International journal of …
# 13            thelancet.com                                       The lancet
# 14        ehp.niehs.nih.gov                Environmental health perspectives
# 15                 Elsevier                        Journal of the American …
# 16                 Springer              Sunlight  vitamin D and skin cancer
# 17   National Acad Sciences                             Proceedings of the …
# 18       iopscience.iop.org                            Physics in Medicine …
# 19                 Elsevier   Journal of the American Academy of Dermatology
#
#                                                Source  cit/year
# 0        https://www.nature.com/articles/nature21056.      1405
# 1   https://www.pnas.org/doi/abs/10.1073/pnas.88.2...        72
# 2   https://www.sciencedirect.com/science/article/...        96
# 3   https://academic.oup.com/bjd/article-abstract/...       159
# 4            https://www.nature.com/articles/372773a0        60
# 5   https://www.nejm.org/doi/full/10.1056/nejmra02...        86
# 6   https://academic.oup.com/bjd/article-abstract/...        80
# 7   https://jamanetwork.com/journals/jamadermatolo...       175
# 8   https://jamanetwork.com/journals/jamadermatolo...       104
# 9   https://www.sciencedirect.com/science/article/...        48
# 10  https://www.pnas.org/doi/abs/10.1073/pnas.71.9...        28
# 11  https://academic.oup.com/jnci/article-abstract...        22
# 12  https://onlinelibrary.wiley.com/doi/abs/10.111...        81
# 13  https://www.thelancet.com/journals/lancet/arti...        73
# 14  https://ehp.niehs.nih.gov/doi/abs/10.1289/ehp....        22
# 15  https://www.sciencedirect.com/science/article/...        39
# 16  https://link.springer.com/chapter/10.1007/978-...        59
# 17  https://www.pnas.org/doi/abs/10.1073/pnas.90.9...        29
# 18  https://iopscience.iop.org/article/10.1088/003...        41
# 19  https://www.sciencedirect.com/science/article/...        39

# %% [markdown]
# Above we have the top 20 papers of deep learning ranked by citations per year. It is incredible that some papers are very far away from the original rank.

# %%
#write only top 20 entries into csv file
print(df.head(20).to_csv("skin_cancer_20.csv"))
# Out:
# None

# %% [markdown]
# Finally, let's download the CSV results (make sure to update the CSV name here as well):

# %%
from google.colab import files
files.download('skin_cancer.csv') # Update the file name here

# %% [markdown]
# OBS: If you get an error running the previous line, you can download the file manually by clicking in the left pane icon (below the `+ Code` button), then click in files, expand the `sort-google-scholar` folder, right click and download in the csv file:
#
# ![](https://i.stack.imgur.com/KKJXFm.png)
